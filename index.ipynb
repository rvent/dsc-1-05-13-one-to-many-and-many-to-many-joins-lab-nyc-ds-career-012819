# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

df1 = pd.DataFrame(cur.execute("""SELECT firstName, lastName, city, state FROM employees 
JOIN offices USING(employee) ORDER BY firstName, lastName""").fetchall())
print(len(df1))
df1
# Out:
# 23
#            0          1              2           3
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
query_result = cur.execute("""SELECT *, orderNumber, orderDate, status 
FROM customers JOIN orders USING(customerNumber);""").fetchall()
df2 = pd.DataFrame(query_result)
print(len(df2))
df2
# Out:
# 326
#       0                               1           2            3   \
# 0    103               Atelier graphique     Schmitt      Carine
# 1    103               Atelier graphique     Schmitt      Carine
# 2    103               Atelier graphique     Schmitt      Carine
# 3    112              Signal Gift Stores        King         Jean
# 4    112              Signal Gift Stores        King         Jean
# 5    112              Signal Gift Stores        King         Jean
# 6    114      Australian Collectors, Co.    Ferguson        Peter
# 7    114      Australian Collectors, Co.    Ferguson        Peter
# 8    114      Australian Collectors, Co.    Ferguson        Peter
# 9    114      Australian Collectors, Co.    Ferguson        Peter
# 10   114      Australian Collectors, Co.    Ferguson        Peter
# 11   119               La Rochelle Gifts     Labrune      Janine
# 12   119               La Rochelle Gifts     Labrune      Janine
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
query_result = cur.execute("""SELECT * FROM orders JOIN orderdetails
USING(orderNumber)""").fetchall()
df3 = pd.DataFrame(query_result)
print(len(df3))
df3
# Out:
# 2996
#          0           1           2           3           4   \
# 0     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 1     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 2     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 3     10100  2003-01-06  2003-01-13  2003-01-10     Shipped
# 4     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 5     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 6     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 7     10101  2003-01-09  2003-01-18  2003-01-11     Shipped
# 8     10102  2003-01-10  2003-01-18  2003-01-14     Shipped
# 9     10102  2003-01-10  2003-01-18  2003-01-14     Shipped
# 10    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 11    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 12    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# 13    10103  2003-01-29  2003-02-07  2003-02-02     Shipped
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
# Your code here
query_result = cur.execute("""SELECT orders.orderNumber, products.* FROM orders JOIN orderdetails
USING(orderNumber) JOIN products USING(productCode)""").fetchall()
df4 = pd.DataFrame(query_result)
print(len(df4))
df4
# Out:
# 2996
#           0          1                                            2  \
# 0     10100   S18_1749                     1917 Grand Touring Sedan
# 1     10100   S18_2248                           1911 Ford Town Car
# 2     10100   S18_4409          1932 Alfa Romeo 8C2300 Spider Sport
# 3     10100   S24_3969             1936 Mercedes Benz 500k Roadster
# 4     10101   S18_2325                    1932 Model A Ford J-Coupe
# 5     10101   S18_2795                       1928 Mercedes-Benz SSK
# 6     10101   S24_1937                  1939 Chevrolet Deluxe Coupe
# 7     10101   S24_2022    1938 Cadillac V-16 Presidential Limousine
# 8     10102   S18_1342                         1937 Lincoln Berline
# 9     10102   S18_1367     1936 Mercedes-Benz 500K Special Roadster
# 10    10103   S10_1949                     1952 Alpine Renault 1300
# 11    10103   S10_4962                       1962 LanciaA Delta 16V
# 12    10103   S12_1666                               1958 Setra Bus
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
